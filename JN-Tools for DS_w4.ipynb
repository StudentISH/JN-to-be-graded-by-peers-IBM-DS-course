# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Irina Shakalo**
#
# analist

# %% [markdown]
# *I am interested in data science because it could describe and explain different global processes: commercial, social, natural etc*

# %% [markdown]
# ### next cell presents some simple math exercise

# %%
2-5*7
# Out:
# -33

# %% [markdown]
# 1. The To Do List
# 2. The Not To Do List
#      * never Not To Do List
#      * almost never Not To Do List
#      * some times To Do List

# %% [markdown]
# ![baba-yaga-picture-childrens-book-260nw-1587328282.webp](attachment:0707e443-96a8-40c1-a40c-519a363d82a0.webp)

# %% [markdown]
# column 1 | column 2 | column 3
# --- | --- | ---
# cell r1 c1 | cell r1 c2 | cell r1 c3
# cell r2 c1 | cell r2 c2 | cell r2 c3
# cell r3 c1 | cell r3 c2 | cell r3 c3
